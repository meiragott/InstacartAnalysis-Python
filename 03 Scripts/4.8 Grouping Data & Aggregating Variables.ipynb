# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ### This script contains the following points:
#
# ## Part One: Tasks from the Exercies
# - **01. Importing Libraries**
# - **02. Importing Data**
# - **03. Create Data Subset - df**
# - **04. Grouping Data**
# - **05. Performing Aggregations**
# - **06.  Create a Loyaty Flag**
# - **07. Deriving Columns with loc()**
#
# ## Part Two: Exercise Task
# - **08. Calculate Mean for Entire Dataframe**
# - **09. Create Loyalty Flag for Existing Customers**
# - **10. Analyzing Customer Spending by Loyality Level**
# - **11. Customer Spending Classification for Targeted Marketing Campaigns**
# - **12. Creating Order Frequency Flags for Targeted User Engagement**
# - **13. Export Dataframe as a Pickle File**

# %% [markdown]
# # Part One: Tasks from the Exercies

# %% [markdown]
# ## 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
# Turn Path into a String & Assign Python Shortcut
path = '/Users/mgottlieb/Documents/Achievement 4'

# %%
# Import the orders_products_merg_busiest_times_and_days.pkl dataset (the export from last task)
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merg_busiest_times_and_days.pkl'))

# %% [markdown]
# ## 03. Create Data Subset [df]

# %%
# Create a subset of the dataframe
df = ords_prods_merge[:1000000]

# %%
# Check the import
df.shape
# Out:
# (1000000, 19)

# %%
# Check the import
df.head()
# Out:
#    order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0   2539329        1             prior             1                   2
# 1   2398795        1             prior             2                   3
# 2    473747        1             prior             3                   3
# 3   2254736        1             prior             4                   4
# 4    431534        1             prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                  8                     7.0                               1
# 1                  7                    15.0                               0
# 2                 12                    21.0                               0
# 3                  7                    29.0                               0
# 4                 15                    28.0                               0
#
#    product_id  add_to_cart_order  reordered _merge product_name  aisle_id  \
# 0         196                  1          0   both         Soda        77
# 1         196                  1          1   both         Soda        77
# 2         196                  1          1   both         Soda        77
# 3         196                  1          1   both         Soda        77
# 4         196                  1          1   both         Soda        77
#
#    department_id  prices    price_range_loc    busiest_days  \
# 0              7     9.0  Mid-range product  Regularly busy
# 1              7     9.0  Mid-range product    Slowest days
# 2              7     9.0  Mid-range product    Slowest days
# 3              7     9.0  Mid-range product    Slowest days
# 4              7     9.0  Mid-range product    Slowest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2        Average orders
# 3        Average orders
# 4        Average orders

# %% [markdown]
# ## 04. Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# ## 05. Performing Aggregations

# %%
# Split subset of data into groups based on "department_id" and apply agg function
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Calculate the mean
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## 06.  Create a Loyaty Flag

# %%
# Split the data (user_id), transform function (generate max orders per user), create a new column (max_order) for results
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/79/dbxtn02s0kzdngngl4z03wch0000gp/T/ipykernel_35393/2602500041.py:2: FutureWarning: The provided callable <function max at 0x11181b880> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Use the string 'max' instead of np.max to ensure future compatibility and avoid the warning.
ords_prods_merge['max_order'] = ords_prods_merge.groupby('user_id')['order_number'].transform('max')

# %%
# Checking the output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0    2539329        1             prior             1                   2
# 1    2398795        1             prior             2                   3
# 2     473747        1             prior             3                   3
# 3    2254736        1             prior             4                   4
# 4     431534        1             prior             5                   4
# 5    3367565        1             prior             6                   2
# 6     550135        1             prior             7                   1
# 7    3108588        1             prior             8                   1
# 8    2295261        1             prior             9                   1
# 9    2550362        1             prior            10                   4
# 10   2968173       15             prior            15                   1
# 11   1870022       15             prior            17                   2
# 12   1911383       15             prior            18                   2
# 13   2715276       15             prior            21                   1
# 14    487368       15             prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                   8                     7.0                               1
# 1                   7                    15.0                               0
# 2                  12                    21.0                               0
# 3                   7                    29.0                               0
# 4                  15                    28.0                               0
# 5                   7                    19.0                               0
# 6                   9                    20.0                               0
# 7                  14                    14.0                               0
# 8                  16                     0.0                               0
# 9                   8                    30.0                               0
# 10                  9                     7.0                               0
# 11                 16                     8.0                               0
# 12                 11                     7.0                               0
# 13                  9                     7.0                               0
# 14                 10                    14.0                               0
#
#     product_id  add_to_cart_order  reordered _merge product_name  aisle_id  \
# 0          196                  1          0   both         Soda        77
# 1          196                  1          1   both         Soda        77
# 2          196                  1          1   both         Soda        77
# 3          196                  1          1   both         Soda        77
# 4          196                  1          1   both         Soda        77
# 5          196                  1          1   both         Soda        77
# 6          196                  1          1   both         Soda        77
# 7          196                  2          1   both         Soda        77
# 8          196                  4          1   both         Soda        77
# 9          196                  1          1   both         Soda        77
# 10         196                  2          0   both         Soda        77
# 11         196                  6          1   both         Soda        77
# 12         196                  1          1   both         Soda        77
# 13         196                  1          1   both         Soda        77
# 14         196                  1          1   both         Soda        77
#
#     department_id  prices    price_range_loc    busiest_days  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1               7     9.0  Mid-range product    Slowest days
# 2               7     9.0  Mid-range product    Slowest days
# 3               7     9.0  Mid-range product    Slowest days
# 4               7     9.0  Mid-range product    Slowest days
# 5               7     9.0  Mid-range product  Regularly busy
# 6               7     9.0  Mid-range product    Busiest days
# 7               7     9.0  Mid-range product    Busiest days
# 8               7     9.0  Mid-range product    Busiest days
# 9               7     9.0  Mid-range product    Slowest days
# 10              7     9.0  Mid-range product    Busiest days
# 11              7     9.0  Mid-range product  Regularly busy
# 12              7     9.0  Mid-range product  Regularly busy
# 13              7     9.0  Mid-range product    Busiest days
# 14              7     9.0  Mid-range product    Busiest days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# 5         Average orders         10
# 6         Average orders         10
# 7         Average orders         10
# 8         Average orders         10
# 9         Average orders         10
# 10        Average orders         22
# 11        Average orders         22
# 12        Average orders         22
# 13        Average orders         22
# 14        Average orders         22

# %%
# Display the first 15 rows with only 'user_id' and 'max_order' columns
print(ords_prods_merge.loc[:, ['user_id', 'max_order']].head(15))
# Out:
#     user_id  max_order
# 0         1         10
# 1         1         10
# 2         1         10
# 3         1         10
# 4         1         10
# 5         1         10
# 6         1         10
# 7         1         10
# 8         1         10
# 9         1         10
# 10       15         22
# 11       15         22
# 12       15         22
# 13       15         22
# 14       15         22

# %% [markdown]
# ## 07. Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print the frequency of the new column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# # Part Two: Exercise Task

# %% [markdown]
# ## 08. Calculate Mean for Entire Dataframe

# %%
# Split the ENTIRE datafram into groups based on "department_id" and apply agg function
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# For the means of the whole dataframe, this first thing to note is that this includes a comprehensive list of **ALL** department ids, not just 4, 7, 13, 14, 16, 17, 19, and 20.\
# \
# If comparing those department ids that are listed in both the subset and the entire dataset, we can see that the majority of the means are slightly higher in the subset:
# #### Some of the means are slightly higher in the subset than the entire dataframe:
# * Department_id: 4*
# * Department_id: 7*
# * Department_id: 13*
# * Department_id: 14*
# * Department_id: 16*
# * Department_id: 19*
# * Department_id: 20*
#
# ***Note: Department_id: 17 is the only subset that is slightly lower in the subset***\
# Since most departments in the subset experience higher mean order numbers than the overall average the subset does not accurately reflect the entire dataset.\
# \
# For the **entire dataset**, we can see that there are a few departments with:
# *Highest Frequency: 10, 18, 21*
# *Moderate Frequency: 2, 3, 4, 7, 16, 19*
# *Lower Frequency: 1, 5, 6, 8, 9, 12, 13, 14, 15, 17, 20*
# \
# \
# Seeing these results, we can then look deeper into to identify data points that are of importance for the highest and lowest frequecy.

# %% [markdown]
# ## 09. Create Loyalty Flag for Existing Customers

# %%
# Checking the dataframe to see the previously created max_order and loyalty_flag
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0    2539329        1             prior             1                   2
# 1    2398795        1             prior             2                   3
# 2     473747        1             prior             3                   3
# 3    2254736        1             prior             4                   4
# 4     431534        1             prior             5                   4
# 5    3367565        1             prior             6                   2
# 6     550135        1             prior             7                   1
# 7    3108588        1             prior             8                   1
# 8    2295261        1             prior             9                   1
# 9    2550362        1             prior            10                   4
# 10   2968173       15             prior            15                   1
# 11   1870022       15             prior            17                   2
# 12   1911383       15             prior            18                   2
# 13   2715276       15             prior            21                   1
# 14    487368       15             prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                   8                     7.0                               1
# 1                   7                    15.0                               0
# 2                  12                    21.0                               0
# 3                   7                    29.0                               0
# 4                  15                    28.0                               0
# 5                   7                    19.0                               0
# 6                   9                    20.0                               0
# 7                  14                    14.0                               0
# 8                  16                     0.0                               0
# 9                   8                    30.0                               0
# 10                  9                     7.0                               0
# 11                 16                     8.0                               0
# 12                 11                     7.0                               0
# 13                  9                     7.0                               0
# 14                 10                    14.0                               0
#
#     product_id  add_to_cart_order  ...  _merge product_name aisle_id  \
# 0          196                  1  ...    both         Soda       77
# 1          196                  1  ...    both         Soda       77
# 2          196                  1  ...    both         Soda       77
# 3          196                  1  ...    both         Soda       77
# 4          196                  1  ...    both         Soda       77
# 5          196                  1  ...    both         Soda       77
# 6          196                  1  ...    both         Soda       77
# 7          196                  2  ...    both         Soda       77
# 8          196                  4  ...    both         Soda       77
# 9          196                  1  ...    both         Soda       77
# 10         196                  2  ...    both         Soda       77
# 11         196                  6  ...    both         Soda       77
# 12         196                  1  ...    both         Soda       77
# 13         196                  1  ...    both         Soda       77
# 14         196                  1  ...    both         Soda       77
#
#     department_id  prices    price_range_loc    busiest_days  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1               7     9.0  Mid-range product    Slowest days
# 2               7     9.0  Mid-range product    Slowest days
# 3               7     9.0  Mid-range product    Slowest days
# 4               7     9.0  Mid-range product    Slowest days
# 5               7     9.0  Mid-range product  Regularly busy
# 6               7     9.0  Mid-range product    Busiest days
# 7               7     9.0  Mid-range product    Busiest days
# 8               7     9.0  Mid-range product    Busiest days
# 9               7     9.0  Mid-range product    Slowest days
# 10              7     9.0  Mid-range product    Busiest days
# 11              7     9.0  Mid-range product  Regularly busy
# 12              7     9.0  Mid-range product  Regularly busy
# 13              7     9.0  Mid-range product    Busiest days
# 14              7     9.0  Mid-range product    Busiest days
#
#    busiest_period_of_day max_order      loyalty_flag
# 0         Average orders        10      New customer
# 1         Average orders        10      New customer
# 2         Average orders        10      New customer
# 3         Average orders        10      New customer
# 4         Average orders        10      New customer
# 5         Average orders        10      New customer
# 6         Average orders        10      New customer
# 7         Average orders        10      New customer
# 8         Average orders        10      New customer
# 9         Average orders        10      New customer
# 10        Average orders        22  Regular customer
# 11        Average orders        22  Regular customer
# 12        Average orders        22  Regular customer
# 13        Average orders        22  Regular customer
# 14        Average orders        22  Regular customer
#
# [15 rows x 21 columns]

# %%
# Drop the previously created 'loyalty_flag' and 'max_order' columns directly in the original DataFrame
ords_prods_merge.drop(columns=['loyalty_flag', 'max_order'], inplace=True)

# %%
# Checking to make sure columns were dropped
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0    2539329        1             prior             1                   2
# 1    2398795        1             prior             2                   3
# 2     473747        1             prior             3                   3
# 3    2254736        1             prior             4                   4
# 4     431534        1             prior             5                   4
# 5    3367565        1             prior             6                   2
# 6     550135        1             prior             7                   1
# 7    3108588        1             prior             8                   1
# 8    2295261        1             prior             9                   1
# 9    2550362        1             prior            10                   4
# 10   2968173       15             prior            15                   1
# 11   1870022       15             prior            17                   2
# 12   1911383       15             prior            18                   2
# 13   2715276       15             prior            21                   1
# 14    487368       15             prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                   8                     7.0                               1
# 1                   7                    15.0                               0
# 2                  12                    21.0                               0
# 3                   7                    29.0                               0
# 4                  15                    28.0                               0
# 5                   7                    19.0                               0
# 6                   9                    20.0                               0
# 7                  14                    14.0                               0
# 8                  16                     0.0                               0
# 9                   8                    30.0                               0
# 10                  9                     7.0                               0
# 11                 16                     8.0                               0
# 12                 11                     7.0                               0
# 13                  9                     7.0                               0
# 14                 10                    14.0                               0
#
#     product_id  add_to_cart_order  reordered _merge product_name  aisle_id  \
# 0          196                  1          0   both         Soda        77
# 1          196                  1          1   both         Soda        77
# 2          196                  1          1   both         Soda        77
# 3          196                  1          1   both         Soda        77
# 4          196                  1          1   both         Soda        77
# 5          196                  1          1   both         Soda        77
# 6          196                  1          1   both         Soda        77
# 7          196                  2          1   both         Soda        77
# 8          196                  4          1   both         Soda        77
# 9          196                  1          1   both         Soda        77
# 10         196                  2          0   both         Soda        77
# 11         196                  6          1   both         Soda        77
# 12         196                  1          1   both         Soda        77
# 13         196                  1          1   both         Soda        77
# 14         196                  1          1   both         Soda        77
#
#     department_id  prices    price_range_loc    busiest_days  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1               7     9.0  Mid-range product    Slowest days
# 2               7     9.0  Mid-range product    Slowest days
# 3               7     9.0  Mid-range product    Slowest days
# 4               7     9.0  Mid-range product    Slowest days
# 5               7     9.0  Mid-range product  Regularly busy
# 6               7     9.0  Mid-range product    Busiest days
# 7               7     9.0  Mid-range product    Busiest days
# 8               7     9.0  Mid-range product    Busiest days
# 9               7     9.0  Mid-range product    Slowest days
# 10              7     9.0  Mid-range product    Busiest days
# 11              7     9.0  Mid-range product  Regularly busy
# 12              7     9.0  Mid-range product  Regularly busy
# 13              7     9.0  Mid-range product    Busiest days
# 14              7     9.0  Mid-range product    Busiest days
#
#    busiest_period_of_day
# 0         Average orders
# 1         Average orders
# 2         Average orders
# 3         Average orders
# 4         Average orders
# 5         Average orders
# 6         Average orders
# 7         Average orders
# 8         Average orders
# 9         Average orders
# 10        Average orders
# 11        Average orders
# 12        Average orders
# 13        Average orders
# 14        Average orders

# %%
# Split the data (user_id), transform function (generate max orders per user), create a new column (max_order) for results
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/79/dbxtn02s0kzdngngl4z03wch0000gp/T/ipykernel_35393/2602500041.py:2: FutureWarning: The provided callable <function max at 0x11181b880> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking to make sure column was added
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0    2539329        1             prior             1                   2
# 1    2398795        1             prior             2                   3
# 2     473747        1             prior             3                   3
# 3    2254736        1             prior             4                   4
# 4     431534        1             prior             5                   4
# 5    3367565        1             prior             6                   2
# 6     550135        1             prior             7                   1
# 7    3108588        1             prior             8                   1
# 8    2295261        1             prior             9                   1
# 9    2550362        1             prior            10                   4
# 10   2968173       15             prior            15                   1
# 11   1870022       15             prior            17                   2
# 12   1911383       15             prior            18                   2
# 13   2715276       15             prior            21                   1
# 14    487368       15             prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                   8                     7.0                               1
# 1                   7                    15.0                               0
# 2                  12                    21.0                               0
# 3                   7                    29.0                               0
# 4                  15                    28.0                               0
# 5                   7                    19.0                               0
# 6                   9                    20.0                               0
# 7                  14                    14.0                               0
# 8                  16                     0.0                               0
# 9                   8                    30.0                               0
# 10                  9                     7.0                               0
# 11                 16                     8.0                               0
# 12                 11                     7.0                               0
# 13                  9                     7.0                               0
# 14                 10                    14.0                               0
#
#     product_id  add_to_cart_order  reordered _merge product_name  aisle_id  \
# 0          196                  1          0   both         Soda        77
# 1          196                  1          1   both         Soda        77
# 2          196                  1          1   both         Soda        77
# 3          196                  1          1   both         Soda        77
# 4          196                  1          1   both         Soda        77
# 5          196                  1          1   both         Soda        77
# 6          196                  1          1   both         Soda        77
# 7          196                  2          1   both         Soda        77
# 8          196                  4          1   both         Soda        77
# 9          196                  1          1   both         Soda        77
# 10         196                  2          0   both         Soda        77
# 11         196                  6          1   both         Soda        77
# 12         196                  1          1   both         Soda        77
# 13         196                  1          1   both         Soda        77
# 14         196                  1          1   both         Soda        77
#
#     department_id  prices    price_range_loc    busiest_days  \
# 0               7     9.0  Mid-range product  Regularly busy
# 1               7     9.0  Mid-range product    Slowest days
# 2               7     9.0  Mid-range product    Slowest days
# 3               7     9.0  Mid-range product    Slowest days
# 4               7     9.0  Mid-range product    Slowest days
# 5               7     9.0  Mid-range product  Regularly busy
# 6               7     9.0  Mid-range product    Busiest days
# 7               7     9.0  Mid-range product    Busiest days
# 8               7     9.0  Mid-range product    Busiest days
# 9               7     9.0  Mid-range product    Slowest days
# 10              7     9.0  Mid-range product    Busiest days
# 11              7     9.0  Mid-range product  Regularly busy
# 12              7     9.0  Mid-range product  Regularly busy
# 13              7     9.0  Mid-range product    Busiest days
# 14              7     9.0  Mid-range product    Busiest days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# 5         Average orders         10
# 6         Average orders         10
# 7         Average orders         10
# 8         Average orders         10
# 9         Average orders         10
# 10        Average orders         22
# 11        Average orders         22
# 12        Average orders         22
# 13        Average orders         22
# 14        Average orders         22

# %% [markdown]
# I can see that the new column of max_order has been created

# %%
# Use loc function to make loyalty flag column
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequency of values in new loyalty flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking the relevant columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# This looks correct so I can move on to analyzing customer spending

# %% [markdown]
# ## 10. Analyzing Customer Spending by Loyality Level

# %% [markdown]
# The marketing team at Instacart is interested in understanding whether there are differences in the spending habits of customers based on their loyalty levels. Specifically, they want to investigate if the prices of products purchased by loyal customers differ from those bought by regular or new customers.

# %%
# Calculate summary statistics for product prices within each loyalty category
ords_prods_merge.groupby('loyalty_flag')['prices'].agg(['mean', 'median', 'std', 'min', 'max'])
# Out:
#                        mean  median         std  min      max
# loyalty_flag
# Loyal customer    10.386336     7.4  328.017787  1.0  99999.0
# New customer      13.294670     7.4  597.560299  1.0  99999.0
# Regular customer  12.495717     7.4  539.720919  1.0  99999.0

# %% [markdown]
# In looking at these results, the results are:
# - **Loyal customers have the lowest average spending per product 10.39 compared to New 13.29 and Regular Customers 12.50.**
# - This is suprising that loyal customers have the lowest average in terms of spending.

# %% [markdown]
# ## 11. Customer Spending Classification for Targeted Marketing Campaigns

# %% [markdown]
# To target different types of spenders in their marketing campaigns, Instacart wants to classify each user as a "Low spender" or a "High spender" based on the average price of the products they purchase.

# %% [markdown]
# - **Condition 1:** If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
#
# - **Condition 2:** If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#
# - **Condition 3:** If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”

# %%
# Use transform() to determine the mean price of products purchased by each user
ords_prods_merge['user_avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/79/dbxtn02s0kzdngngl4z03wch0000gp/T/ipykernel_35393/2064092695.py:2: FutureWarning: The provided callable <function mean at 0x1118242c0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['user_avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Checking the output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_status  order_number  orders_day_of_week  \
# 0    2539329        1             prior             1                   2
# 1    2398795        1             prior             2                   3
# 2     473747        1             prior             3                   3
# 3    2254736        1             prior             4                   4
# 4     431534        1             prior             5                   4
# 5    3367565        1             prior             6                   2
# 6     550135        1             prior             7                   1
# 7    3108588        1             prior             8                   1
# 8    2295261        1             prior             9                   1
# 9    2550362        1             prior            10                   4
# 10   2968173       15             prior            15                   1
# 11   1870022       15             prior            17                   2
# 12   1911383       15             prior            18                   2
# 13   2715276       15             prior            21                   1
# 14    487368       15             prior            22                   1
#
#     order_hour_of_day  days_since_prior_order  days_since_prior_order_missing  \
# 0                   8                     7.0                               1
# 1                   7                    15.0                               0
# 2                  12                    21.0                               0
# 3                   7                    29.0                               0
# 4                  15                    28.0                               0
# 5                   7                    19.0                               0
# 6                   9                    20.0                               0
# 7                  14                    14.0                               0
# 8                  16                     0.0                               0
# 9                   8                    30.0                               0
# 10                  9                     7.0                               0
# 11                 16                     8.0                               0
# 12                 11                     7.0                               0
# 13                  9                     7.0                               0
# 14                 10                    14.0                               0
#
#     product_id  add_to_cart_order  ...  product_name aisle_id department_id  \
# 0          196                  1  ...          Soda       77             7
# 1          196                  1  ...          Soda       77             7
# 2          196                  1  ...          Soda       77             7
# 3          196                  1  ...          Soda       77             7
# 4          196                  1  ...          Soda       77             7
# 5          196                  1  ...          Soda       77             7
# 6          196                  1  ...          Soda       77             7
# 7          196                  2  ...          Soda       77             7
# 8          196                  4  ...          Soda       77             7
# 9          196                  1  ...          Soda       77             7
# 10         196                  2  ...          Soda       77             7
# 11         196                  6  ...          Soda       77             7
# 12         196                  1  ...          Soda       77             7
# 13         196                  1  ...          Soda       77             7
# 14         196                  1  ...          Soda       77             7
#
#     prices    price_range_loc    busiest_days busiest_period_of_day max_order  \
# 0      9.0  Mid-range product  Regularly busy        Average orders        10
# 1      9.0  Mid-range product    Slowest days        Average orders        10
# 2      9.0  Mid-range product    Slowest days        Average orders        10
# 3      9.0  Mid-range product    Slowest days        Average orders        10
# 4      9.0  Mid-range product    Slowest days        Average orders        10
# 5      9.0  Mid-range product  Regularly busy        Average orders        10
# 6      9.0  Mid-range product    Busiest days        Average orders        10
# 7      9.0  Mid-range product    Busiest days        Average orders        10
# 8      9.0  Mid-range product    Busiest days        Average orders        10
# 9      9.0  Mid-range product    Slowest days        Average orders        10
# 10     9.0  Mid-range product    Busiest days        Average orders        22
# 11     9.0  Mid-range product  Regularly busy        Average orders        22
# 12     9.0  Mid-range product  Regularly busy        Average orders        22
# 13     9.0  Mid-range product    Busiest days        Average orders        22
# 14     9.0  Mid-range product    Busiest days        Average orders        22
#
#         loyalty_flag  user_avg_price
# 0       New customer        6.367797
# 1       New customer        6.367797
# 2       New customer        6.367797
# 3       New customer        6.367797
# 4       New customer        6.367797
# 5       New customer        6.367797
# 6       New customer        6.367797
# 7       New customer        6.367797
# 8       New customer        6.367797
# 9       New customer        6.367797
# 10  Regular customer        3.980556
# 11  Regular customer        3.980556
# 12  Regular customer        3.980556
# 13  Regular customer        3.980556
# 14  Regular customer        3.980556
#
# [15 rows x 22 columns]

# %%
# Create spending flag column based off of the given criteria
ords_prods_merge.loc[ords_prods_merge['user_avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['user_avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check the frequency of the new column
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# Checking relevant columns
ords_prods_merge[['user_id', 'user_avg_price', 'spending_flag']].head(15)
# Out:
#     user_id  user_avg_price spending_flag
# 0         1        6.367797   Low spender
# 1         1        6.367797   Low spender
# 2         1        6.367797   Low spender
# 3         1        6.367797   Low spender
# 4         1        6.367797   Low spender
# 5         1        6.367797   Low spender
# 6         1        6.367797   Low spender
# 7         1        6.367797   Low spender
# 8         1        6.367797   Low spender
# 9         1        6.367797   Low spender
# 10       15        3.980556   Low spender
# 11       15        3.980556   Low spender
# 12       15        3.980556   Low spender
# 13       15        3.980556   Low spender
# 14       15        3.980556   Low spender

# %% [markdown]
# ## 12. Creating Order Frequency Flags for Targeted User Engagement

# %% [markdown]
# Instacart seeks to boost user engagement by sending personalized notifications tailored to customers' ordering frequencies. To achieve this, I need to categorize customers by the median days between their orders, allowing for targeted communication based on how frequently they shop.

# %%
# Calculate the median days since prior order for each user
ords_prods_merge['user_median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/79/dbxtn02s0kzdngngl4z03wch0000gp/T/ipykernel_35393/2720989673.py:2: FutureWarning: The provided callable <function median at 0x111968360> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['user_median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking the output of relevent columns
ords_prods_merge.loc[:, ['user_id', 'days_since_prior_order', 'user_median_days']].head(15)
# Out:
#     user_id  days_since_prior_order  user_median_days
# 0         1                     7.0              20.0
# 1         1                    15.0              20.0
# 2         1                    21.0              20.0
# 3         1                    29.0              20.0
# 4         1                    28.0              20.0
# 5         1                    19.0              20.0
# 6         1                    20.0              20.0
# 7         1                    14.0              20.0
# 8         1                     0.0              20.0
# 9         1                    30.0              20.0
# 10       15                     7.0               8.0
# 11       15                     8.0               8.0
# 12       15                     7.0               8.0
# 13       15                     7.0               8.0
# 14       15                    14.0               8.0

# %%
# Creating frequency flags
ords_prods_merge.loc[ords_prods_merge['user_median_days'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['user_median_days'] > 10) & (ords_prods_merge['user_median_days'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['user_median_days'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Print the frequency of the new column
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        22790523
# Regular customer          6927608
# Non-frequent customer     2686728
# Name: count, dtype: int64

# %%
# Check the relevant and new columns
ords_prods_merge[['user_id', 'days_since_prior_order', 'user_median_days', 'order_frequency_flag']].head(20)
# Out:
#     user_id  days_since_prior_order  user_median_days order_frequency_flag
# 0         1                     7.0              20.0     Regular customer
# 1         1                    15.0              20.0     Regular customer
# 2         1                    21.0              20.0     Regular customer
# 3         1                    29.0              20.0     Regular customer
# 4         1                    28.0              20.0     Regular customer
# 5         1                    19.0              20.0     Regular customer
# 6         1                    20.0              20.0     Regular customer
# 7         1                    14.0              20.0     Regular customer
# 8         1                     0.0              20.0     Regular customer
# 9         1                    30.0              20.0     Regular customer
# 10       15                     7.0               8.0    Frequent customer
# 11       15                     8.0               8.0    Frequent customer
# 12       15                     7.0               8.0    Frequent customer
# 13       15                     7.0               8.0    Frequent customer
# 14       15                    14.0               8.0    Frequent customer
# 15       19                     6.0               7.0    Frequent customer
# 16       19                     8.0               7.0    Frequent customer
# 17       19                     6.0               7.0    Frequent customer
# 18       21                     6.0               7.0    Frequent customer
# 19       31                     7.0               6.0    Frequent customer

# %% [markdown]
# ## 12. Export Dataframe as a Pickle File

# %%
# Export dataframe to pkl file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_flags_grouped.pkl'))
